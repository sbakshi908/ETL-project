# %%
# Dependencies

import pandas as pd
from config import cloudM, cloudMpassword
import requests
import pymongo
import pandas as pd
from pymongo import MongoClient

# %%
#in this notenook I will extract the table of the most recent champions from each major tennis tournament 

us_open_url = 'https://en.wikipedia.org/wiki/US_Open_(tennis)'
us_open_table = pd.read_html(us_open_url)
us_open_table
# Out:
# [                                                0  \
#  0                                             NaN
#  1                                Official website
#  2                                         Founded
#  3                                        Editions
#  4                                        Location
#  5                                           Venue
#  6                                         Surface
#  7                                     Prize money
#  8                                           Men's
#  9                                            Draw
#  10                              Current champions
#  11                            Most singles titles
#  12                            Most doubles titles
#  13                                        Women's
#  14                                           Draw
#  15                              Current champions
#  16                            Most singles titles
# ...

# %%
#extract the correct table
us_df = us_open_table[4]
us_df
# Out:
#                    Event                            Champion  \
# 0    Men's singles final                       Dominic Thiem
# 1  Women's singles final                         Naomi Osaka
# 2    Men's doubles final             Mate Pavić Bruno Soares
# 3  Women's doubles final      Laura Siegemund Vera Zvonareva
# 4    Mixed doubles final  Bethanie Mattek-Sands Jamie Murray
#
#                       Runner-up                         Score
# 0              Alexander Zverev  2–6, 4–6, 6–4, 6–3, 7–6(8–6)
# 1             Victoria Azarenka                 1–6, 6–3, 6–3
# 2  Wesley Koolhof Nikola Mektić                      7–5, 6–3
# 3      Nicole Melichar Xu Yifan                      6–4, 6–4
# 4  Chan Hao-ching Michael Venus                      6–2, 6–3

# %%
#add new column for tournament name distinguising later in Mongo 
tourn_name = ['US Open', 'US Open', 'US Open', 'US Open', 'US Open']

us_df["Tournament"] = tourn_name
us_df
# Out:
#                    Event                            Champion  \
# 0    Men's singles final                       Dominic Thiem
# 1  Women's singles final                         Naomi Osaka
# 2    Men's doubles final             Mate Pavić Bruno Soares
# 3  Women's doubles final      Laura Siegemund Vera Zvonareva
# 4    Mixed doubles final  Bethanie Mattek-Sands Jamie Murray
#
#                       Runner-up                         Score Tournament
# 0              Alexander Zverev  2–6, 4–6, 6–4, 6–3, 7–6(8–6)    US Open
# 1             Victoria Azarenka                 1–6, 6–3, 6–3    US Open
# 2  Wesley Koolhof Nikola Mektić                      7–5, 6–3    US Open
# 3      Nicole Melichar Xu Yifan                      6–4, 6–4    US Open
# 4  Chan Hao-ching Michael Venus                      6–2, 6–3    US Open

# %%
aus_open_url = 'https://en.wikipedia.org/wiki/Australian_Open'
aus_open_table = pd.read_html(aus_open_url)

# %%
aus_df = aus_open_table[3]
aus_df
# Out:
#              Event                       Champion  \
# 0    Men's Singles                 Novak Djokovic
# 1  Women's Singles                    Naomi Osaka
# 2    Men's Doubles       Ivan Dodig Filip Polášek
# 3  Women's Doubles  Elise Mertens Aryna Sabalenka
# 4    Mixed Doubles  Barbora Krejčíková Rajeev Ram
#
#                                Runner-up          Score
# 0                        Daniil Medvedev  7–5, 6–2, 6–2
# 1                         Jennifer Brady       6–4, 6–3
# 2               Rajeev Ram Joe Salisbury       6–3, 6–4
# 3  Barbora Krejčíková Kateřina Siniaková       6–2, 6–3
# 4          Samantha Stosur Matthew Ebden       6–1, 6–4

# %%
tourn_name = ['Aus Open', 'Aus Open', 'Aus Open', 'Aus Open','Aus Open' ]
aus_df["Tournament"] = tourn_name
aus_df
# Out:
#              Event                       Champion  \
# 0    Men's Singles                 Novak Djokovic
# 1  Women's Singles                    Naomi Osaka
# 2    Men's Doubles       Ivan Dodig Filip Polášek
# 3  Women's Doubles  Elise Mertens Aryna Sabalenka
# 4    Mixed Doubles  Barbora Krejčíková Rajeev Ram
#
#                                Runner-up          Score Tournament
# 0                        Daniil Medvedev  7–5, 6–2, 6–2   Aus Open
# 1                         Jennifer Brady       6–4, 6–3   Aus Open
# 2               Rajeev Ram Joe Salisbury       6–3, 6–4   Aus Open
# 3  Barbora Krejčíková Kateřina Siniaková       6–2, 6–3   Aus Open
# 4          Samantha Stosur Matthew Ebden       6–1, 6–4   Aus Open

# %%
french_open_url = 'https://en.wikipedia.org/wiki/French_Open'
french_open_table = pd.read_html(french_open_url)

# %%
french_df = french_open_table[2]
french_df
# Out:
#              Event                         Champion  \
# 0    Men's Singles                     Rafael Nadal
# 1  Women's Singles                      Iga Świątek
# 2    Men's Doubles      Kevin Krawietz Andreas Mies
# 3  Women's Doubles  Tímea Babos Kristina Mladenovic
# 4    Mixed Doubles          Latisha Chan Ivan Dodig
#
#                          Runner-up          Score
# 0                   Novak Djokovic  6–0, 6–2, 7–5
# 1                      Sofia Kenin       6–4, 6–1
# 2          Mate Pavić Bruno Soares       6–3, 7–5
# 3  Alexa Guarachi Desirae Krawczyk       6–4, 7–5
# 4    Gabriela Dabrowski Mate Pavić  6–1, 7–6(7–5)

# %%
tourn_name = ['French Open', 'French Open', 'French Open','French Open','French Open']
french_df['Tournament'] = tourn_name
french_df
# Out:
#              Event                         Champion  \
# 0    Men's Singles                     Rafael Nadal
# 1  Women's Singles                      Iga Świątek
# 2    Men's Doubles      Kevin Krawietz Andreas Mies
# 3  Women's Doubles  Tímea Babos Kristina Mladenovic
# 4    Mixed Doubles          Latisha Chan Ivan Dodig
#
#                          Runner-up          Score   Tournament
# 0                   Novak Djokovic  6–0, 6–2, 7–5  French Open
# 1                      Sofia Kenin       6–4, 6–1  French Open
# 2          Mate Pavić Bruno Soares       6–3, 7–5  French Open
# 3  Alexa Guarachi Desirae Krawczyk       6–4, 7–5  French Open
# 4    Gabriela Dabrowski Mate Pavić  6–1, 7–6(7–5)  French Open

# %%
wim_open_url = 'https://en.wikipedia.org/wiki/The_Championships,_Wimbledon'
wim_open_table = pd.read_html(wim_open_url)

# %%
wim_df = wim_open_table[3]
wim_df
# Out:
#                  Event                           Champion  \
# 0  Gentlemen's Singles                     Novak Djokovic
# 1      Ladies' Singles                       Simona Halep
# 2  Gentlemen's Doubles  Juan Sebastián Cabal Robert Farah
# 3      Ladies' Doubles      Barbora Strýcová Su-Wei Hsieh
# 4        Mixed Doubles            Latisha Chan Ivan Dodig
#
#                               Runner-up  \
# 0                         Roger Federer
# 1                       Serena Williams
# 2  Nicolas Mahut Édouard Roger-Vasselin
# 3           Gabriela Dabrowski Xu Yifan
# 4     Jeļena Ostapenko Robert Lindstedt
#
#                                          Score
# 0     7–6(7–5), 1–6, 7–6(7–4), 4–6, 13–12(7–3)
# 1                                     6–2, 6–2
# 2  6–7(5–7), 7–6(7–5), 7–6(8–6), 6–7(5–7), 6–3
# 3                                     6–2, 6–4
# 4                                     6–2, 6–3

# %%
tourn_name = ['Wimbledon','Wimbledon', 'Wimbledon', 'Wimbledon', 'Wimbledon' ]
wim_df['Tournament'] = tourn_name
wim_df
# Out:
#                  Event                           Champion  \
# 0  Gentlemen's Singles                     Novak Djokovic
# 1      Ladies' Singles                       Simona Halep
# 2  Gentlemen's Doubles  Juan Sebastián Cabal Robert Farah
# 3      Ladies' Doubles      Barbora Strýcová Su-Wei Hsieh
# 4        Mixed Doubles            Latisha Chan Ivan Dodig
#
#                               Runner-up  \
# 0                         Roger Federer
# 1                       Serena Williams
# 2  Nicolas Mahut Édouard Roger-Vasselin
# 3           Gabriela Dabrowski Xu Yifan
# 4     Jeļena Ostapenko Robert Lindstedt
#
#                                          Score Tournament
# 0     7–6(7–5), 1–6, 7–6(7–4), 4–6, 13–12(7–3)  Wimbledon
# 1                                     6–2, 6–2  Wimbledon
# 2  6–7(5–7), 7–6(7–5), 7–6(8–6), 6–7(5–7), 6–3  Wimbledon
# 3                                     6–2, 6–4  Wimbledon
# 4                                     6–2, 6–3  Wimbledon

# %%
mongodb+srv://sbakshi908:<password>@summyamongo.afc2i.mongodb.net/myFirstDatabase?retryWrites=true&w=majority
# Out:
#   File "<ipython-input-14-1998952abc8b>", line 1
#     mongodb+srv://sbakshi908:<password>@summyamongo.afc2i.mongodb.net/myFirstDatabase?retryWrites=true&w=majority
#                 ^
# SyntaxError: invalid syntax

# %%
#make the mongo connection
client = MongoClient()
#method 1 local
#client = MongoClient('localhost', 27017)


#cloud_string = 'mongodb+srv://'+cloudM+':'+cloudMpassword+'@summyamongo.afc2i.mongodb.net/myFirstDatabase?retryWrites=true&w=majority'
#method 2 cloud 
cloud_str = f"mongodb+srv://sbakshi908:{cloudMpassword}@summyamongo.afc2i.mongodb.net/myFirstDatabase?retryWrites=true&w=majority"
client = MongoClient(cloud_str)

# %%
print(cloud_string)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-661117a498c5> in <module>
# ----> 1 print(cloud_string)
#
# NameError: name 'cloud_string' is not defined

# %%
# Declare the database
db = client.ETLdb

# Declare the collection
coll = db.tourn_champs
coll.drop()

# %%
#iterate through each row in df (we will have to do this 4 times)
for index, row in us_df.iterrows():
    print (row)
    coll.insert_one(row.to_dict())
# Out:
# Event                  Men's singles final
# Champion                     Dominic Thiem
# Runner-up                 Alexander Zverev
# Score         2–6, 4–6, 6–4, 6–3, 7–6(8–6)
# Tournament                         US Open
# Name: 0, dtype: object
# Event         Women's singles final
# Champion                Naomi Osaka
# Runner-up         Victoria Azarenka
# Score                 1–6, 6–3, 6–3
# Tournament                  US Open
# Name: 1, dtype: object
# Event                  Men's doubles final
# Champion           Mate Pavić Bruno Soares
# Runner-up     Wesley Koolhof Nikola Mektić
# Score                             7–5, 6–3
# Tournament                         US Open
# Name: 2, dtype: object
# Event                  Women's doubles final
# Champion      Laura Siegemund Vera Zvonareva
# Runner-up           Nicole Melichar Xu Yifan
# Score                               6–4, 6–4
# Tournament                           US Open
# Name: 3, dtype: object
# ...

# %%
#create a variable for the dictionary that will be inserted into the collection
us_open_dict = us_df.to_dict('records')

# %%
#insert to collection
coll.insert_many(us_open_dict)

# %% [markdown]
# ### Next the Australian Open

# %%
#iterate through each row in df (we will have to do this 4 times)
for index, row in aus_df.iterrows():
    print (row)
    coll.insert_one(row.to_dict())
# Out:
# Event           Men's Singles
# Champion       Novak Djokovic
# Runner-up     Daniil Medvedev
# Score           7–5, 6–2, 6–2
# Tournament           Aus Open
# Name: 0, dtype: object
# Event         Women's Singles
# Champion          Naomi Osaka
# Runner-up      Jennifer Brady
# Score                6–4, 6–3
# Tournament           Aus Open
# Name: 1, dtype: object
# Event                    Men's Doubles
# Champion      Ivan Dodig Filip Polášek
# Runner-up     Rajeev Ram Joe Salisbury
# Score                         6–3, 6–4
# Tournament                    Aus Open
# Name: 2, dtype: object
# Event                               Women's Doubles
# Champion              Elise Mertens Aryna Sabalenka
# Runner-up     Barbora Krejčíková Kateřina Siniaková
# Score                                      6–2, 6–3
# Tournament                                 Aus Open
# Name: 3, dtype: object
# Event                         Mixed Doubles
# Champion      Barbora Krejčíková Rajeev Ram
# ...

# %%
#create a variable for the dictionary that will be inserted into the collection
aus_open_dict = aus_df.to_dict('records')

# %%
#insert to collection
coll.insert_many(aus_open_dict)

# %% [markdown]
# ### Now French Open

# %%
#iterate through each row in df (we will have to do this 4 times)
for index, row in french_df.iterrows():
    print (row)
    coll.insert_one(row.to_dict())
# Out:
# Event          Men's Singles
# Champion        Rafael Nadal
# Runner-up     Novak Djokovic
# Score          6–0, 6–2, 7–5
# Tournament       French Open
# Name: 0, dtype: object
# Event         Women's Singles
# Champion          Iga Świątek
# Runner-up         Sofia Kenin
# Score                6–4, 6–1
# Tournament        French Open
# Name: 1, dtype: object
# Event                       Men's Doubles
# Champion      Kevin Krawietz Andreas Mies
# Runner-up         Mate Pavić Bruno Soares
# Score                            6–3, 7–5
# Tournament                    French Open
# Name: 2, dtype: object
# Event                         Women's Doubles
# Champion      Tímea Babos Kristina Mladenovic
# Runner-up     Alexa Guarachi Desirae Krawczyk
# Score                                6–4, 7–5
# Tournament                        French Open
# Name: 3, dtype: object
# Event                         Mixed Doubles
# Champion            Latisha Chan Ivan Dodig
# ...

# %%
#create a variable for the dictionary that will be inserted into the collection
french_open_dict = french_df.to_dict('records')

# %%
#insert to collection
coll.insert_many(french_open_dict)

# %% [markdown]
# ### Last Wimbledon

# %%
#iterate through each row in df (we will have to do this 4 times)
for index, row in wim_df.iterrows():
    print (row)
    coll.insert_one(row.to_dict())
# Out:
# Event                              Gentlemen's Singles
# Champion                                Novak Djokovic
# Runner-up                                Roger Federer
# Score         7–6(7–5), 1–6, 7–6(7–4), 4–6, 13–12(7–3)
# Tournament                                   Wimbledon
# Name: 0, dtype: object
# Event         Ladies' Singles
# Champion         Simona Halep
# Runner-up     Serena Williams
# Score                6–2, 6–2
# Tournament          Wimbledon
# Name: 1, dtype: object
# Event                                 Gentlemen's Doubles
# Champion                Juan Sebastián Cabal Robert Farah
# Runner-up            Nicolas Mahut Édouard Roger-Vasselin
# Score         6–7(5–7), 7–6(7–5), 7–6(8–6), 6–7(5–7), 6–3
# Tournament                                      Wimbledon
# Name: 2, dtype: object
# Event                       Ladies' Doubles
# Champion      Barbora Strýcová Su-Wei Hsieh
# Runner-up       Gabriela Dabrowski Xu Yifan
# ...

# %%
#create a variable for the dictionary that will be inserted into the collection
wim_open_dict = wim_df.to_dict('records')

# %%
#insert to collection
coll.insert_many(wim_open_dict)
